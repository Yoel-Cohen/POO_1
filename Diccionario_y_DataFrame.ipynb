# %%
import pandas as pd

# %% [markdown]
# #Diccionario

# %%
up={"Clases": ["Fisica", "Calculo", "Poo"],
    "salones": 3,
    "profesor": ["oscar", "Pablo"],
    "Las_chidas": {"limon": 25,
                   "limon_preparado":30,
                   "picantes":23.50}}

# %%
up.keys() #enseña las llaves del diccionario
# Out:
# dict_keys(['Clases', 'salones', 'profesor', 'Las_chidas'])

# %%
up.values() #objetos de un diccionario
# Out:
# dict_values([['Fisica', 'Calculo', 'Poo'], 3, ['oscar', 'Pablo'], {'limon': 25, 'limon_preparado': 30, 'picantes': 23.5}])

# %%
#transformamos las llaves y valores usando la funcion in-built list
lista_up= list(up.values())

# %%
#accesos
print(up["Clases"])
print(lista_up[2])
# Out:
# ['Fisica', 'Calculo', 'Poo']
# ['oscar', 'Pablo']

# %%
dicc={"Yoel": [2, "Bacardi", "7"],
      "Max":[7, "Lala", 78],
      "marcos":[8, "alexa", 56],} #Yoel es la llave y lo demas son los objetos

# %% [markdown]
# #DataFrames

# %%
df= pd.DataFrame(dicc)
df
# Out:
#       Yoel   Max marcos
# 0        2     7      8
# 1  Bacardi  Lala  alexa
# 2        7    78     56

# %% [markdown]
# #Vamos a poder leer

# %%
spotify= pd.read_csv("spotify-2023.csv",encoding='latin-1')
spotify
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# #Lectura desde drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
spot= pd.read_csv("/content/drive/MyDrive/POO-2024_Yoel/Most Streamed Spotify Songs 2024.csv", encoding="latin-1")
spot
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC All Time Rank  Track Score  \
# ...
